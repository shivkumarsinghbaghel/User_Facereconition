# %% [markdown]
# ## Face Recognition – Unlock Your Computer With Your Face!

# %%
import cv2
import pyttsx3 as sp
import numpy as np
import time
import os
#file
from os import listdir
from os.path import isfile, join
#whatsapp
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
#Mail
import smtplib
from email.message import EmailMessage
import getpass

# %% [markdown]
# # Step 1 - Create Training Data

# %%
def user_data(duserpath,user_name):
 # Load HAAR face classifier

 face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
 print(duserpath)
 # Load functions
 def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

# Initialize Webcam
 cap = cv2.VideoCapture(0)
 count = 0
# Collect 100 samples of your face from webcam input
 print("Picking Images For : {}".format(user_name))
 sp.speak("picking Images For : {}".format(user_name))
 print("Store Images At ->{} for user {}".format(duserpath,user_name))
 sp.speak("Store Images At ->{} for user {}".format(duserpath,user_name))
 while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        print("*",end="")
        face = cv2.resize(face_extractor(frame), (200, 200))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Save file in specified directory with unique name
        file_name_path = duserpath + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Face not found")
        sp.speak("Face not found ")
        pass

    if cv2.waitKey(1) == 13 or count == 100: #13 is the Enter Key
        break
        
 cap.release()
 cv2.destroyAllWindows()      
 print("Image Samples Complete")
 sp.speak("Image Samples Complete")
# Out:
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-33-d7ec339da63d>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %% [markdown]
# ### Step 2 - Train Model

# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join
def train(tuserpath,user_name) :
 # Get the training data we previously made
 #userpath=input("Enter User :")
 data_path = tuserpath
 print("Start Training Model . . . .")
 sp.speak("Start Training Model")
 onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]

 # Create arrays for training data and labels
 Training_Data, Labels = [], []

 # Open training images in our datapath
 # Create a numpy array for training data
 print("Collecting Images From ->{} for user {}".format(data_path,user_name))
 sp.speak("Collecting Images From ->{} for user {}".format(data_path,user_name))
 for i, files in enumerate(onlyfiles):
    print("*",end="")
    image_path = data_path + onlyfiles[i]
    images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    Training_Data.append(np.asarray(images, dtype=np.uint8))
    Labels.append(i)

 # Create a numpy array for both training data and labels
 Labels = np.asarray(Labels, dtype=np.int32)

# Initialize facial recognizer
# model = cv2.face.createLBPHFaceRecognizer()
# NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()
# pip install opencv-contrib-python
# model = cv2.createLBPHFaceRecognizer()


#first step for user basedmodel

 return Training_Data,Labels
 #shiv_model  = cv2.face.LBPHFaceRecognizer_create()
# Let's train our model 
#shiv_model.train(np.asarray(Training_Data), np.asarray(Labels))
#sp.speak("model trained successfully")
#print("Model trained sucessefully")

# %%
def whatsapp_message():
            sp.speak("welcome to whatsapp ")
            sp.speak("login to your account")
            print("opening whatsapp")
            sp.speak("opening whatsapp")
            browser = webdriver.Chrome(r'C:\Users\Lenovo\Downloads\chromedriver_win32\chromedriver')
            browser.get('https://web.whatsapp.com')
            friend = input('Enter your friend name: ')
            sp.speak("Enter your message")
            message = input('Enter your message: ')
            print("sending ....")

            searchbox = browser.find_element_by_xpath('//*[@id="side"]/div[1]/div/label/div/div[2]')
            searchbox.send_keys(friend)
            searchbox.send_keys(Keys.ENTER)
            
            messagebox = browser.find_element_by_xpath('//*[@id="main"]/footer/div[1]/div[2]/div/div[2]')
            messagebox.send_keys(message)
            messagebox.send_keys(Keys.ENTER)
            print(" message sent")
            print("Done")

# %%
def mail(subject,body,to,user):
    msg =EmailMessage()
    msg.set_content(body)
    msg['subject'] = subject
    msg['to'] = to
    msg['from'] = user
    sp.speak('Enter your password')
    password = getpass.getpass(prompt='Enter password :')
    server = smtplib.SMTP("smtp.gmail.com",587)
    server.starttls()
    server.login(user,password)
    server.send_message(msg)
    sp.speak('mail sent successfully')
    print('Mail sent Successfully')
    server.quit()


def send_mail() :
    #sp.speak("enter srnder email")
    user ="2018pietcsshiv131@poornima.org"
    #print("Enter Receiver Email :",end="")
    #sp.speak("enter Receiver email")
    rem="shivkumarsingh990@gmail.com"
    print("subject :" ,end="")
    sub=input()
    print("Body :",end="")
    bod=input()
    print("sending Email ....")
    sp.speak("sending email")
    mail(sub, bod, rem,user)

# %%
import time
def aws_instence() :
    sp.speak("start launch insatance")
    os.system("aws ec2 run-instances --image-id ami-0ad704c126371a549  --instance-type t2.micro  --count 1  --subnet-id subnet-d8584fb0 --security-group-ids sg-1cf73e7a --key-name firstkey  ")
    time.sleep(30)
    sp.speak("Instance launch Successfully")
    print("Instance launch Successfully")
    InstanceId = os.popen('''aws ec2 describe-instances --filters Name=instance-state-name,Values=running  --query "Reservations[*].Instances[*].{Instance:InstanceId}" --output text''').read()
    os.system("aws ec2 create-tags --resources i-045c826aae984ee6c --tags Key=Name,Value=MyInstance")
    os.system("aws ec2 create-volume --availability-zone ap-south-1a --volume-type gp2 --size 5")
    time.sleep(30)
    print("Volume created Successfully")
    VolumeId = os.popen('''aws ec2 describe-volumes --filters Name=status,Values=available Name=size,Values=5 --query "Volumes[*].VolumeId" --output text''').read()
    os.system("aws ec2 attach-volume  --volume-id " + VolumeId[:-1] + " --instance-id " + InstanceId[:-1] + " --device /dev/sdf")

# %% [markdown]
# ### Step 3 - Run Our Facial Recognition

# %%
import cv2
import numpy as np
import os

def test_face(user_name,path,Training_Data,Labels):
 face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

 def face_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi

 shiv_model  = cv2.face.LBPHFaceRecognizer_create()
 # Let's train our model 
 shiv_model.train(np.asarray(Training_Data), np.asarray(Labels))
 sp.speak("model trained successfully")
 print("Model trained sucessefully")
 time.sleep(10)
# Open Webcam
 cap = cv2.VideoCapture(0)
 print("Testing Model ")
 sp.speak("starting face recognition")
 while True:

    ret, frame = cap.read()
    
    image, face = face_detector(frame)
    
    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)
        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        results = shiv_model.predict(face)
        # harry_model.predict(face)
        
        if results[1] < 500:
            confidence = int( 100 * (1 - (results[1])/400) )
            display_string = str(confidence) + '% Confident it is {}'.format(user_name)
            
        cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
        
        if confidence > 90:
            cv2.putText(image, "Hey {}".format(user_name), (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
            if user_name == "shiv" : 
             whatsapp_message()                      #whatsapp_message()
            if user_name == "prabhjeet" : 
             mail(subject,body,to,user)              #send_mail()
            
            if user_name == "neeraj" : 
             aws_instence()                          #aws_instence()
            
                
            break
         
        else:
            
            cv2.putText(image, "I dont know, how r u", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )

    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "looking for face", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass
        
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
 cap.release()
 cv2.destroyAllWindows()
# Out:
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-38-f9882773c73d>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
def final_model():
     users = []
     user_name_s = []
     user_path_s = []
     models = []
     Training_Data , Labels = [] , []
     path=input("Enter User :")
     users.append(path)
     user_name=input("Enter User Name :")
     userpath = './faces/{}/'.format(path)
     user_data(userpath,user_name)
     Training_Data,Labels=train(userpath,user_name)
     test_face(user_name,path,Training_Data,Labels)

# %%
final_model()
# Out:
# Enter User :user1
# Enter User Name :shiv
# ./faces/user1/
# Picking Images For : shiv
# Store Images At ->./faces/user1/ for user shiv
# ****************************************************************************************************Image Samples Complete
# Start Training Model . . . .
# ...
# ****************************************************************************************************Model trained sucessefully
# Testing Model
# opening whatsapp
# Enter your friend name: prabhjeet
# Enter your message: hi
# sending ....
#  message sent
# Done

# %%
test_face()

# %%
userpath
